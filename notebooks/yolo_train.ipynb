# %%
a = ['divider-line', 'dotted-line', 'double-line', 'random-line', 'road-sign-line', 'solid-line']

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="IWrrJjGsEeBtZrnljhvt")
project = rf.workspace("hackoleni-7i1hc").project("sdfgsdfgdfghdf")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
import torch

torch.cuda.is_available()
# Out:
# True

# %%
model = YOLO('yolo11x.pt')
model
# Out:
# ...
# 100%|██████████| 109M/109M [00:07<00:00, 14.9MB/s]
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
# ...

# %%
model.train(data='./datasets/sdfgsdfgdfghdf-3/data.yaml',
            epochs=30,
            device='cuda', 
            batch=8)
# Out:
# Ultralytics 8.3.28  Python-3.12.2 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# ...

# %%
# !nvidia-smi
# Out:
# Sun Nov 10 03:38:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.92                 Driver Version: 546.92       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   46C    P8               3W /  44W |   2883MiB /  8188MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...
